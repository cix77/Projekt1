# %%
import pandas as pd

# Beispiel-URL für 311-Lärmklagen zu Fahrzeugen in NYC
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$where=complaint_type='Noise - Vehicle'&$limit=1000"
df = pd.read_csv(url)
print(df.head())
